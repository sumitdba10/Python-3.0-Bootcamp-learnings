# %% [markdown]
# <a href="https://colab.research.google.com/github/sumitdba10/Python-3.0-Bootcamp-learnings/blob/master/Sets_and_Booleans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Sets**
#
# Sets (Object Type) are an unordered collection of unique elements. We can construct them by using the set() function. Let's go ahead and make a set to see how it works

# %%
myset = set()

# %%
type(myset)
# Out:
# set

# %%
myset.add(1)

# %%
myset
# Out:
# {1}

# %%
myset.add(2)

# %%
myset
# Out:
# {1, 2}

# %%
mylist = [1,2,2,3,3,4,4,5]

# %%
mylist
# Out:
# [1, 2, 2, 3, 3, 4, 4, 5]

# %%
set(mylist)
# Out:
# {1, 2, 3, 4, 5}

# %%
list(mylist)
# Out:
# [1, 2, 2, 3, 3, 4, 4, 5]

# %%
set('Mississippi')
# Out:
# {'M', 'i', 'p', 's'}

# %% [markdown]
# **BOOLEAN:**

# %%
True
# Out:
# True

# %%
type(True)
# Out:
# bool

# %%
False
# Out:
# False

# %%
type(False)
# Out:
# bool

# %%
true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-724ba28f4a9a> in <module>()
# ----> 1 true
#
# NameError: name 'true' is not defined

# %%
1.5 > 3.0
# Out:
# False

# %%
1 = 1
# Out:
#   File "<ipython-input-19-ecdac3dcabfd>", line 1
#     1 = 1
#          ^
# SyntaxError: can't assign to literal

# %%
1 == 1
# Out:
# True

# %% [markdown]
# **NONE**
#
# ```
# # This is formatted as code
#
# None type as a placeholder only
# ```

# %%
b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-89e6c98d9288> in <module>()
# ----> 1 b
#
# NameError: name 'b' is not defined

# %%
b = None

# %%
b

# %%
type(b)
# Out:
# NoneType
